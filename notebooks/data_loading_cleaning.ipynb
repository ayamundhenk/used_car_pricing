# %% [markdown]
# # Data Loading and Cleaning
#
# This notebook loads the used car dataset, inspects the raw data, and performs basic data cleaning steps.

# %%
import pandas as pd
from data_prep import load_vehicle_data, display_dataset_overview, get_missing_values, clean_vehicle_data

pd.set_option('display.max_columns', None)

# %%
df = load_vehicle_data()
display_dataset_overview(df)

print('Missing values summary:')
print(get_missing_values(df))

# %% [markdown]
# ## Cleaned dataset

# %%
clean_df = clean_vehicle_data(df)
print(f'Clean dataset shape: {clean_df.shape}')
clean_df.head()
